# %% [markdown]
# ## Computer Vs Computer

# %%
import random 
xox = {'T1': ' ', 'T2':' ','T3':' ',
      'M1': ' ', 'M2':' ','M3':' ',
      'D1': ' ', 'D2':' ','D3':' ',}
player1 = 1
tatal = 0
end_check=0
def check():
    #اول احتمال افقي للفوز 
    if xox['T1'] == 'X' and xox['T2'] == 'X' and xox['T3'] == 'X':
        print("Player PC1 Win!")
        return 1
    #تاني احتمال افقي للفوز 
    if xox['M1'] == 'X' and xox['M2'] == 'X' and xox['M3'] == 'X':
        print("Player PC1 Win!")
        return 1
    #ثالث احتمال افقي للفوز 
    if xox['D1'] == 'X' and xox['D2'] == 'X' and xox['D3'] == 'X':
        print("Player PC1 Win!")
        return 1
    #أول احتمال رئسي للفوز 
    if xox['T1'] == 'X' and xox['M1'] == 'X' and xox['D1'] == 'X':
        print("Player PC1 Win!")
        return 1
    #ثاني احتمال رئسي للفوز 
    if xox['T2'] == 'X' and xox['M2'] == 'X' and xox['D2'] == 'X':
        print("Player PC1 Win!")
        return 1
    #ثالث احتمال رئسي للفوز 
    if xox['T3'] == 'X' and xox['M3'] == 'X' and xox['D3'] == 'X':
        print("Player PC1 Win!")
        return 1
    
    if xox['T1'] == 'X' and xox['M2'] == 'X' and xox['D3'] == 'X':
        print("Player PC1 Win!")
        return 1
    
    if xox['T1'] == 'O' and xox['T2'] == 'O' and xox['T3'] == 'O':
        print("Player PC2 Win!")
        return 1
    if xox['M1'] == 'O' and xox['M2'] == 'O' and xox['M3'] == 'O':
        print("Player PC2 Win!")
        return 1
    if xox['D1'] == 'O' and xox['D2'] == 'O' and xox['D3'] == 'O':
        print("Player PC2 Win!")
        return 1
    
    if xox['T1'] == 'O' and xox['M1'] == 'O' and xox['D1'] == 'O':
        print("Player PC2 Win!")
        return 1
    if xox['T2'] == 'O' and xox['M2'] == 'O' and xox['D2'] == 'O':
        print("Player PC2 Win!")
        return 1
    if xox['T3'] == 'O' and xox['M3'] == 'O' and xox['D3'] == 'O':
        print("Player PC2 Win!")
        return 1
    if xox['D1'] == 'O' and xox['D2'] == 'O' and xox['D3'] == 'O':
        print("Player PC2 Win!")
        return 1
        if xox['T1'] == 'O' and xox['M2'] == 'O' and xox['D3'] == 'O':
            print("Player PC2 Win!")
        return 1
    return 0

while True:
    print(xox['T1'],'|',xox['T2'],'|',xox['T3'])
    print("---------")
    print(xox['M1'],'|',xox['M2'],'|',xox['M3'])
    print("---------")
    print(xox['D1'],'|',xox['D2'],'|',xox['D3'])
    end_check = check()
    if tatal == 9 or end_check == 1:
        print("The End")
        break
    while True:
        if player1 == 1:
            print('player pc1 = ')
            lis1=['t1','t2','t3','m1','m2','m3','d1','d2','d3']
            cp1= random.choice(lis1)
            cc = str(cp1)
            if cc.upper() in xox and xox[cc.upper()] == ' ':
                xox[cc.upper()] = 'X'
                player1 = 2
                break
            else:
                print("invalid please try agin PC1: ")
                continue
        else: 
            print('player pc2 = ')
            lis1=['t1','t2','t3','m1','m2','m3','d1','d2','d3']
            cp1= random.choice(lis1)
            cc = str(cp1)
            if cc.upper() in xox and xox[cc.upper()] == ' ':
                xox[cc.upper()] = 'O'
                player1 = 1
                break
            else:
                print("invalid please try agin PC2: ")
                continue
    tatal +=1
    print("-------------------")
    print()
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# player pc1 =
# -------------------
#
#   |   |
# ---------
#   |   |
# ---------
# X |   |
# player pc2 =
# -------------------
#
# O |   |
# ---------
#   |   |
# ---------
# X |   |
# player pc1 =
# -------------------
#
# O |   |
# ---------
#   |   |
# ---------
# X | X |
# player pc2 =
# invalid please try agin PC2:
# player pc2 =
# invalid please try agin PC2:
# player pc2 =
# -------------------
#
# O |   | O
# ---------
#   |   |
# ---------
# X | X |
# player pc1 =
# -------------------
#
# O |   | O
# ---------
#   |   | X
# ---------
# X | X |
# player pc2 =
# -------------------
#
# O | O | O
# ---------
#   |   | X
# ---------
# X | X |
# Player PC2 Win!
# The End
